# %%
import pandas as pd
from tqdm import tqdm
import os

from sklearn.model_selection import train_test_split
from tensorflow.keras.metrics import Accuracy, Recall, Precision, MeanSquaredError
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Bidirectional, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
from sklearn.model_selection import KFold

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
reviews_cleaned = "/content/drive/MyDrive/NLP_FINAL/data/cleanedDataset.csv"
dataset = pd.read_csv(reviews_cleaned)

# %%
y = dataset["sentiment"].values
X = dataset["text"].values
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2, shuffle=True)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

sequences_length = 50
sequences_train = tokenizer.texts_to_sequences(X_train)
sequences_train = pad_sequences(sequences_train, maxlen=sequences_length)

sequences_test = tokenizer.texts_to_sequences(X_test)
sequences_test = pad_sequences(sequences_test, maxlen=sequences_length)

# %%
vocabulary_size = len(tokenizer.word_index) + 1

# %%
folds = 4
kfold = KFold(n_splits=folds, shuffle=True)

s = []

for train, test in kfold.split(X_train, y_train):
  embedding_dim = 16
  lstm_units = 32

  model = Sequential()
  model.add(Embedding(vocabulary_size, embedding_dim))
  model.add(LSTM(lstm_units))
  model.add(Dropout(.5))
  model.add(Dense(1, activation='sigmoid'))
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', Precision(), Recall(), MeanSquaredError()])
  model.summary()

  model.fit(sequences_train[train], y_train[train], epochs = 5, batch_size=10, verbose = 1)

  scores = model.evaluate(sequences_train[test], y_train[test], verbose=1)
  print("\n\n")
  print(model.metrics_names)
  print(scores)

  s.append(scores)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, None, 16)          1106944
#
#  lstm_9 (LSTM)               (None, 32)                6272
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,113,249
# Trainable params: 1,113,249
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 3435/3435 [==============================] - 119s 34ms/step - loss: 0.3742 - accuracy: 0.8365 - precision_6: 0.8735 - recall_6: 0.9051 - mean_squared_error: 0.1181
# Epoch 2/5
# 3435/3435 [==============================] - 115s 34ms/step - loss: 0.2868 - accuracy: 0.8789 - precision_6: 0.9090 - recall_6: 0.9254 - mean_squared_error: 0.0877
# Epoch 3/5
# 3435/3435 [==============================] - 117s 34ms/step - loss: 0.2442 - accuracy: 0.8999 - precision_6: 0.9226 - recall_6: 0.9407 - mean_squared_error: 0.0737
# Epoch 4/5
# 3435/3435 [==============================] - 116s 34ms/step - loss: 0.2118 - accuracy: 0.9132 - precision_6: 0.9335 - recall_6: 0.9476 - mean_squared_error: 0.0634
# Epoch 5/5
# 3435/3435 [==============================] - 114s 33ms/step - loss: 0.1827 - accuracy: 0.9273 - precision_6: 0.9433 - recall_6: 0.9571 - mean_squared_error: 0.0540
# 358/358 [==============================] - 5s 10ms/step - loss: 0.4050 - accuracy: 0.8493 - precision_6: 0.9003 - recall_6: 0.8940 - mean_squared_error: 0.1147
#
#
#
# ['loss', 'accuracy', 'precision_6', 'recall_6', 'mean_squared_error']
# [0.404997855424881, 0.8493186831474304, 0.9003350138664246, 0.8940240144729614, 0.1147003248333931]
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, None, 16)          1106944
#
#  lstm_10 (LSTM)              (None, 32)                6272
#
#  dropout_10 (Dropout)        (None, 32)                0
#
#  dense_10 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 1,113,249
# Trainable params: 1,113,249
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 3435/3435 [==============================] - 117s 33ms/step - loss: 0.3715 - accuracy: 0.8362 - precision_7: 0.8693 - recall_7: 0.9119 - mean_squared_error: 0.1169
# Epoch 2/5
# 3435/3435 [==============================] - 118s 34ms/step - loss: 0.2840 - accuracy: 0.8812 - precision_7: 0.9095 - recall_7: 0.9292 - mean_squared_error: 0.0863
# Epoch 3/5
# 3435/3435 [==============================] - 117s 34ms/step - loss: 0.2390 - accuracy: 0.9011 - precision_7: 0.9243 - recall_7: 0.9411 - mean_squared_error: 0.0720
# Epoch 4/5
# 3435/3435 [==============================] - 120s 35ms/step - loss: 0.2057 - accuracy: 0.9164 - precision_7: 0.9357 - recall_7: 0.9504 - mean_squared_error: 0.0614
# Epoch 5/5
# 3435/3435 [==============================] - 117s 34ms/step - loss: 0.1755 - accuracy: 0.9292 - precision_7: 0.9445 - recall_7: 0.9590 - mean_squared_error: 0.0523
# 358/358 [==============================] - 4s 7ms/step - loss: 0.3852 - accuracy: 0.8448 - precision_7: 0.8825 - recall_7: 0.9066 - mean_squared_error: 0.1142
#
#
#
# ['loss', 'accuracy', 'precision_7', 'recall_7', 'mean_squared_error']
# [0.3851945400238037, 0.8447763919830322, 0.8824633359909058, 0.906603991985321, 0.11417289078235626]
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_11 (Embedding)    (None, None, 16)          1106944
#
#  lstm_11 (LSTM)              (None, 32)                6272
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_11 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 1,113,249
# Trainable params: 1,113,249
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 3435/3435 [==============================] - 120s 34ms/step - loss: 0.3774 - accuracy: 0.8323 - precision_8: 0.8649 - recall_8: 0.9117 - mean_squared_error: 0.1194
# Epoch 2/5
# 3435/3435 [==============================] - 117s 34ms/step - loss: 0.2875 - accuracy: 0.8771 - precision_8: 0.9062 - recall_8: 0.9269 - mean_squared_error: 0.0880
# Epoch 3/5
# 3435/3435 [==============================] - 117s 34ms/step - loss: 0.2411 - accuracy: 0.8999 - precision_8: 0.9232 - recall_8: 0.9405 - mean_squared_error: 0.0730
# Epoch 4/5
# 3435/3435 [==============================] - 117s 34ms/step - loss: 0.2039 - accuracy: 0.9172 - precision_8: 0.9359 - recall_8: 0.9512 - mean_squared_error: 0.0608
# Epoch 5/5
# 3435/3435 [==============================] - 118s 34ms/step - loss: 0.1708 - accuracy: 0.9307 - precision_8: 0.9473 - recall_8: 0.9580 - mean_squared_error: 0.0507
# 358/358 [==============================] - 4s 8ms/step - loss: 0.3983 - accuracy: 0.8520 - precision_8: 0.8681 - recall_8: 0.9389 - mean_squared_error: 0.1112
#
#
#
# ['loss', 'accuracy', 'precision_8', 'recall_8', 'mean_squared_error']
# [0.39825472235679626, 0.8520265817642212, 0.8680756688117981, 0.9388835430145264, 0.11124417185783386]
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_12 (Embedding)    (None, None, 16)          1106944
#
#  lstm_12 (LSTM)              (None, 32)                6272
#
#  dropout_12 (Dropout)        (None, 32)                0
#
#  dense_12 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 1,113,249
# Trainable params: 1,113,249
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 3435/3435 [==============================] - 120s 34ms/step - loss: 0.3714 - accuracy: 0.8362 - precision_9: 0.8688 - recall_9: 0.9131 - mean_squared_error: 0.1172
# Epoch 2/5
# 3435/3435 [==============================] - 117s 34ms/step - loss: 0.2818 - accuracy: 0.8820 - precision_9: 0.9099 - recall_9: 0.9302 - mean_squared_error: 0.0857
# Epoch 3/5
# 3435/3435 [==============================] - 116s 34ms/step - loss: 0.2394 - accuracy: 0.9003 - precision_9: 0.9226 - recall_9: 0.9423 - mean_squared_error: 0.0722
# Epoch 4/5
# 3435/3435 [==============================] - 116s 34ms/step - loss: 0.2062 - accuracy: 0.9151 - precision_9: 0.9349 - recall_9: 0.9496 - mean_squared_error: 0.0620
# Epoch 5/5
# 3435/3435 [==============================] - 117s 34ms/step - loss: 0.1770 - accuracy: 0.9270 - precision_9: 0.9433 - recall_9: 0.9574 - mean_squared_error: 0.0529
# 358/358 [==============================] - 4s 8ms/step - loss: 0.4373 - accuracy: 0.8500 - precision_9: 0.8682 - recall_9: 0.9336 - mean_squared_error: 0.1155
#
#
#
# ['loss', 'accuracy', 'precision_9', 'recall_9', 'mean_squared_error']
# [0.43734246492385864, 0.8500043749809265, 0.8681777119636536, 0.9335516095161438, 0.11548247188329697]

# %%
import numpy as np

print("avg acc", np.mean([i[1] for i in s]))
print()
# Out:
# avg acc 0.8490315079689026

# %%
acc = model.evaluate(sequences_test, y_test)
# Out:
# 358/358 [==============================] - 3s 7ms/step - loss: 0.4510 - accuracy: 0.8461 - precision_9: 0.8665 - recall_9: 0.9324 - mean_squared_error: 0.1189

# %%
acc
# Out:
# [0.45100492238998413,
#  0.8460866808891296,
#  0.8665032386779785,
#  0.932374119758606,
#  0.11887399852275848]
