# %%
import re
from tqdm import tqdm
import pandas as pd
import numpy as np

import nltk
nltk.download('punkt')
nltk.download('stopwords')

from nltk.stem import PorterStemmer as stemmer
from nltk.corpus import stopwords

import tensorflow as tf
from sklearn.feature_extraction.text import TfidfVectorizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

from sklearn.svm import SVC
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Flatten, Conv1D, GlobalMaxPooling1D, MaxPooling1D, Dropout
from tensorflow.keras.metrics import Recall, Precision, MeanSquaredError

from sklearn.model_selection import cross_val_score, train_test_split, KFold
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score, mean_squared_error
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pande\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pande\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %% [markdown]
# # Data Cleaning

# %%
reviews_labeled = "data/reviews_labeled.csv"
reviews_scored = "data/reviews_scored.csv"

# %%
dataset1 = pd.read_csv(reviews_labeled)
dataset2 = pd.read_csv(reviews_scored)

# %%
dataset1.head()
# Out:
#    User_ID                                        Description  \
# 0  id10326  The room was kind of clean but had a VERY stro...
# 1  id10327  I stayed at the Crown Plaza April -- - April -...
# 2  id10328  I booked this hotel through Hotwire at the low...
# 3  id10329  Stayed here with husband and sons on the way t...
# 4  id10330  My girlfriends and I stayed here to celebrate ...
#
#         Browser_Used Device_Used Is_Response
# 0               Edge      Mobile   not happy
# 1  Internet Explorer      Mobile   not happy
# 2            Mozilla      Tablet   not happy
# 3   InternetExplorer     Desktop       happy
# 4               Edge      Tablet   not happy

# %%
dataset2.head()
# Out:
#                                               Review  Rating
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5

# %% [markdown]
# Cleaning Dataset 1

# %%
# rename columns
dataset1 = dataset1.rename({"Description": "text", "Is_Response": "sentiment"}, axis=1)[["text", "sentiment"]]

# replace not happy to 0 and happy to 1
dataset1.replace("not happy", 0, inplace=True)
dataset1.replace("happy", 1, inplace=True)

# %% [markdown]
# Cleaning Dataset 2

# %%
# rename columns
dataset2 = dataset2.rename({"Review": "text", "Rating": "sentiment"}, axis=1)

# remove data with sentiment values == 3 since we're only looking at values 1-2 for not happy and 4-5 for happy
dataset2 = dataset2[dataset2["sentiment"] != 3]

# converting sentiment score to boolean
sentiments = [0 if x < 3 else 1 for x in dataset2["sentiment"]]
dataset2["sentiment"] = sentiments

# %% [markdown]
# Generating a combined Dataset

# %%
# concatenating datasets
dataset = pd.concat([dataset1, dataset2])

# removing repeated indexes by resetting the index of the dataframe
dataset.reset_index(drop=True, inplace=True)

# %% [markdown]
# Preprocessing

# %%
# function to remove stopwords + numbers + special characters and convert text to lowercase
def preProcess(text):
    sents = nltk.sent_tokenize(text)

    for i in range(len(sents)):
        words = nltk.word_tokenize(sents[i])
        for j in range(len(words)):
            if words[j] not in set(stopwords.words('english')): 
                words[j] = re.sub('[^A-Za-z]+','', words[j]) # maybe add numbers
                words[j] = words[j].lower()
                words[j] = stemmer().stem(words[j])
        sents[i] = ' '.join([w for w in words if w != ""])
    
    sents = ' '.join(sents)
    return sents

# %%
texts = list(dataset["text"])
for i in tqdm(range(len(texts  ))):
    dataset.loc[i, ["text"]] = preProcess(texts[i])
# Out:
# 100%|██████████| 57239/57239 [48:17<00:00, 19.76it/s]

# %% [markdown]
# # Support Vector Machines (SVM)

# %% [markdown]
# TF-IDF Vectorization

# %%
vectorizer = TfidfVectorizer(strip_accents=None, 
                        lowercase=None, 
                        preprocessor=None, 
                        tokenizer=None, 
                        use_idf=True, 
                        norm='l2', 
                        smooth_idf=True)

y = dataset.sentiment.values
X = vectorizer.fit_transform(dataset.text)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)

# %%
model = SVC(kernel='rbf')

# %% [markdown]
# Cross-validation

# %%
scores = cross_val_score(model, X_train, y_train, scoring="neg_mean_squared_error", n_jobs=-1, cv=5)
print('Cross-validation MSE {0:.2f}%'.format(np.mean(scores) * 100))
# Out:
# Cross-validation MSE -8.81%

# %% [markdown]
# Fitting the model on X_train & y_train

# %%
model = SVC(kernel='rbf')
model.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# Testing the Model

# %%
y_pred = model.predict(X_test)

print("Recall", recall_score(y_test, y_pred))
print("Precision", precision_score(y_test, y_pred))
print("F-measure", f1_score(y_test, y_pred))
print("Accuracy", accuracy_score(y_test, y_pred))
# Out:
# Recall 0.9565947242206235
# Precision 0.9250927643784786
# F-measure 0.940580051874558
# Accuracy 0.9119496855345912

# %% [markdown]
# # Convolutional Neural Networks (CNN)

# %%
y = dataset.sentiment.values
X = dataset.text.values
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)

# %% [markdown]
# Preprocessing

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# converting text to sequences
sequences_length = 50
sequences_train = tokenizer.texts_to_sequences(X_train)
sequences_train = pad_sequences(sequences_train, maxlen=sequences_length)

sequences_test = tokenizer.texts_to_sequences(X_test)
sequences_test = pad_sequences(sequences_test, maxlen=sequences_length)

# +1 for OOV words
vocabulary_size = len(tokenizer.word_index) + 1

# %%
def CNN_Model(seq_len):
    embedding_dim = 16
    units = 32
    
    model = Sequential()
    model.add(Embedding(vocabulary_size, embedding_dim, input_length=seq_len))
    model.add(Conv1D(filters=units, kernel_size=8, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', Recall(), Precision(), MeanSquaredError()])
    
    return model

# %% [markdown]
# Cross-validation

# %%
folds = 5
kfold = KFold(n_splits=folds, shuffle=True)

scores = []
for train, test in kfold.split(X_train, y_train):
    model = CNN_Model(sequences_length)
    model.summary()
    
    model.fit(sequences_train[train], y_train[train], epochs = 3, batch_size=10, verbose = 1)
    
    s = model.evaluate(sequences_train[test], y_train[test], verbose=1)
    scores.append(s)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 50, 16)            1106944
#
#  conv1d_2 (Conv1D)           (None, 43, 32)            4128
#
#  max_pooling1d_2 (MaxPooling  (None, 21, 32)           0
#  1D)
#
#  flatten_2 (Flatten)         (None, 672)               0
#
#  dense_4 (Dense)             (None, 10)                6730
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 1,117,813
# Trainable params: 1,117,813
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 3664/3664 [==============================] - 37s 9ms/step - loss: 0.3583 - accuracy: 0.8386 - recall_2: 0.9173 - precision_2: 0.8677 - mean_squared_error: 0.1137
# Epoch 2/3
# 3664/3664 [==============================] - 33s 9ms/step - loss: 0.2507 - accuracy: 0.8960 - recall_2: 0.9392 - precision_2: 0.9192 - mean_squared_error: 0.0763
# Epoch 3/3
# 3664/3664 [==============================] - 33s 9ms/step - loss: 0.1683 - accuracy: 0.9329 - recall_2: 0.9593 - precision_2: 0.9488 - mean_squared_error: 0.0498
# 287/287 [==============================] - 1s 1ms/step - loss: 0.4020 - accuracy: 0.8474 - recall_2: 0.9201 - precision_2: 0.8772 - mean_squared_error: 0.1137
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 50, 16)            1106944
#
#  conv1d_3 (Conv1D)           (None, 43, 32)            4128
#
#  max_pooling1d_3 (MaxPooling  (None, 21, 32)           0
#  1D)
#
#  flatten_3 (Flatten)         (None, 672)               0
#
#  dense_6 (Dense)             (None, 10)                6730
#
#  dense_7 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 1,117,813
# Trainable params: 1,117,813
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 3664/3664 [==============================] - 35s 9ms/step - loss: 0.3612 - accuracy: 0.8350 - recall_3: 0.9200 - precision_3: 0.8625 - mean_squared_error: 0.1150
# Epoch 2/3
# 3664/3664 [==============================] - 34s 9ms/step - loss: 0.2567 - accuracy: 0.8927 - recall_3: 0.9370 - precision_3: 0.9174 - mean_squared_error: 0.0783
# Epoch 3/3
# 3664/3664 [==============================] - 34s 9ms/step - loss: 0.1781 - accuracy: 0.9268 - recall_3: 0.9572 - precision_3: 0.9431 - mean_squared_error: 0.0531
# 287/287 [==============================] - 1s 1ms/step - loss: 0.3953 - accuracy: 0.8504 - recall_3: 0.9166 - precision_3: 0.8809 - mean_squared_error: 0.1122
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 50, 16)            1106944
#
#  conv1d_4 (Conv1D)           (None, 43, 32)            4128
#
#  max_pooling1d_4 (MaxPooling  (None, 21, 32)           0
#  1D)
#
#  flatten_4 (Flatten)         (None, 672)               0
#
#  dense_8 (Dense)             (None, 10)                6730
#
#  dense_9 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 1,117,813
# Trainable params: 1,117,813
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 3664/3664 [==============================] - 35s 9ms/step - loss: 0.3595 - accuracy: 0.8351 - recall_4: 0.9194 - precision_4: 0.8629 - mean_squared_error: 0.1147
# Epoch 2/3
# 3664/3664 [==============================] - 34s 9ms/step - loss: 0.2534 - accuracy: 0.8936 - recall_4: 0.9390 - precision_4: 0.9168 - mean_squared_error: 0.0774
# Epoch 3/3
# 3664/3664 [==============================] - 34s 9ms/step - loss: 0.1774 - accuracy: 0.9304 - recall_4: 0.9593 - precision_4: 0.9458 - mean_squared_error: 0.0522
# 287/287 [==============================] - 1s 1ms/step - loss: 0.3749 - accuracy: 0.8497 - recall_4: 0.9095 - precision_4: 0.8857 - mean_squared_error: 0.1113
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 50, 16)            1106944
#
#  conv1d_5 (Conv1D)           (None, 43, 32)            4128
#
#  max_pooling1d_5 (MaxPooling  (None, 21, 32)           0
#  1D)
#
#  flatten_5 (Flatten)         (None, 672)               0
#
#  dense_10 (Dense)            (None, 10)                6730
#
#  dense_11 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 1,117,813
# Trainable params: 1,117,813
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 3664/3664 [==============================] - 35s 9ms/step - loss: 0.3595 - accuracy: 0.8359 - recall_5: 0.9218 - precision_5: 0.8616 - mean_squared_error: 0.1145
# Epoch 2/3
# 3664/3664 [==============================] - 35s 10ms/step - loss: 0.2527 - accuracy: 0.8919 - recall_5: 0.9360 - precision_5: 0.9168 - mean_squared_error: 0.0776
# Epoch 3/3
# 3664/3664 [==============================] - 37s 10ms/step - loss: 0.1763 - accuracy: 0.9292 - recall_5: 0.9582 - precision_5: 0.9449 - mean_squared_error: 0.0523
# 287/287 [==============================] - 1s 1ms/step - loss: 0.3962 - accuracy: 0.8469 - recall_5: 0.8976 - precision_5: 0.8936 - mean_squared_error: 0.1146
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 50, 16)            1106944
#
#  conv1d_6 (Conv1D)           (None, 43, 32)            4128
#
#  max_pooling1d_6 (MaxPooling  (None, 21, 32)           0
#  1D)
#
#  flatten_6 (Flatten)         (None, 672)               0
#
#  dense_12 (Dense)            (None, 10)                6730
#
#  dense_13 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 1,117,813
# Trainable params: 1,117,813
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 3664/3664 [==============================] - 35s 9ms/step - loss: 0.3570 - accuracy: 0.8373 - recall_6: 0.9197 - precision_6: 0.8650 - mean_squared_error: 0.1136
# Epoch 2/3
# 3664/3664 [==============================] - 36s 10ms/step - loss: 0.2519 - accuracy: 0.8933 - recall_6: 0.9359 - precision_6: 0.9188 - mean_squared_error: 0.0770
# Epoch 3/3
# 3664/3664 [==============================] - 34s 9ms/step - loss: 0.1770 - accuracy: 0.9292 - recall_6: 0.9570 - precision_6: 0.9462 - mean_squared_error: 0.0527
# 287/287 [==============================] - 1s 1ms/step - loss: 0.4326 - accuracy: 0.8482 - recall_6: 0.9335 - precision_6: 0.8675 - mean_squared_error: 0.1162

# %% [markdown]
# CV Metrics

# %%
for j, name in enumerate(model.metrics_names):
    print(f"{name}:", np.mean([score[model.metrics_names.index(name)] for score in scores]))
# Out:
# loss: 0.4002059757709503
# accuracy: 0.8485292077064515
# recall_6: 0.915476942062378
# precision_6: 0.880971896648407
# mean_squared_error: 0.11361034214496613

# %% [markdown]
# Test Metrics

# %%
model = CNN_Model(sequences_length)
model.fit(sequences_train, y_train, epochs=3, batch_size=10, verbose=1)
metrics = model.evaluate(sequences_test, y_test, verbose=1)
# Out:
# Epoch 1/3
# 4580/4580 [==============================] - 40s 9ms/step - loss: 0.3598 - accuracy: 0.8351 - recall_8: 0.9264 - precision_8: 0.8580 - mean_squared_error: 0.1146
# Epoch 2/3
# 4580/4580 [==============================] - 41s 9ms/step - loss: 0.2612 - accuracy: 0.8886 - recall_8: 0.9366 - precision_8: 0.9124 - mean_squared_error: 0.0802
# Epoch 3/3
# 4580/4580 [==============================] - 41s 9ms/step - loss: 0.1956 - accuracy: 0.9204 - recall_8: 0.9546 - precision_8: 0.9370 - mean_squared_error: 0.0585
# 358/358 [==============================] - 1s 1ms/step - loss: 0.3845 - accuracy: 0.8526 - recall_8: 0.9314 - precision_8: 0.8745 - mean_squared_error: 0.1093

# %% [markdown]
# # Long Short Term Memory (LSTM)

# %%
def LSTM_Model():
    embedding_dim = 16
    lstm_units = 32
    
    model = Sequential()
    model.add(Embedding(vocabulary_size, embedding_dim))
    model.add(LSTM(lstm_units))
    model.add(Dropout(.5))
    model.add(Dense(1, activation='sigmoid'))
    
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', Precision(), Recall(), MeanSquaredError()])
    
    return model

# %% [markdown]
# Cross-validation

# %%
folds = 5
kfold = KFold(n_splits=folds, shuffle=True)

scores = []
for train, test in kfold.split(X_train, y_train):
    model = LSTM_Model()
    model.summary()
    
    model.fit(sequences_train[train], y_train[train], epochs = 3, batch_size=10, verbose = 1)
    
    s = model.evaluate(sequences_train[test], y_train[test], verbose=1)
    
    scores.append(s)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, None, 16)          1106944
#
#  lstm (LSTM)                 (None, 32)                6272
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_18 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 1,113,249
# Trainable params: 1,113,249
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 3664/3664 [==============================] - 75s 20ms/step - loss: 0.3731 - accuracy: 0.8363 - precision_9: 0.8715 - recall_9: 0.9086 - mean_squared_error: 0.1175
# Epoch 2/3
# 3664/3664 [==============================] - 70s 19ms/step - loss: 0.2840 - accuracy: 0.8817 - precision_9: 0.9090 - recall_9: 0.9302 - mean_squared_error: 0.0865
# Epoch 3/3
# 3664/3664 [==============================] - 71s 19ms/step - loss: 0.2417 - accuracy: 0.9005 - precision_9: 0.9229 - recall_9: 0.9416 - mean_squared_error: 0.0727
# 287/287 [==============================] - 2s 6ms/step - loss: 0.3461 - accuracy: 0.8492 - precision_9: 0.8710 - recall_9: 0.9307 - mean_squared_error: 0.1080
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, None, 16)          1106944
#
#  lstm_1 (LSTM)               (None, 32)                6272
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_19 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 1,113,249
# Trainable params: 1,113,249
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 3664/3664 [==============================] - 74s 20ms/step - loss: 0.3738 - accuracy: 0.8356 - precision_10: 0.8709 - recall_10: 0.9087 - mean_squared_error: 0.1177
# Epoch 2/3
# 3664/3664 [==============================] - 72s 20ms/step - loss: 0.2884 - accuracy: 0.8789 - precision_10: 0.9077 - recall_10: 0.9280 - mean_squared_error: 0.0879
# Epoch 3/3
# 3664/3664 [==============================] - 71s 19ms/step - loss: 0.2466 - accuracy: 0.8967 - precision_10: 0.9203 - recall_10: 0.9394 - mean_squared_error: 0.0747
# 287/287 [==============================] - 2s 5ms/step - loss: 0.3722 - accuracy: 0.8516 - precision_10: 0.8967 - recall_10: 0.8982 - mean_squared_error: 0.1116
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_11 (Embedding)    (None, None, 16)          1106944
#
#  lstm_2 (LSTM)               (None, 32)                6272
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_20 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 1,113,249
# Trainable params: 1,113,249
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 3664/3664 [==============================] - 74s 19ms/step - loss: 0.3716 - accuracy: 0.8383 - precision_11: 0.8705 - recall_11: 0.9139 - mean_squared_error: 0.1165
# Epoch 2/3
# 3664/3664 [==============================] - 71s 19ms/step - loss: 0.2836 - accuracy: 0.8801 - precision_11: 0.9076 - recall_11: 0.9300 - mean_squared_error: 0.0864
# Epoch 3/3
# 3664/3664 [==============================] - 72s 20ms/step - loss: 0.2414 - accuracy: 0.9012 - precision_11: 0.9238 - recall_11: 0.9421 - mean_squared_error: 0.0729
# 287/287 [==============================] - 2s 5ms/step - loss: 0.3727 - accuracy: 0.8499 - precision_11: 0.8946 - recall_11: 0.8974 - mean_squared_error: 0.1116
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_12 (Embedding)    (None, None, 16)          1106944
#
#  lstm_3 (LSTM)               (None, 32)                6272
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_21 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 1,113,249
# Trainable params: 1,113,249
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 3664/3664 [==============================] - 76s 20ms/step - loss: 0.3748 - accuracy: 0.8347 - precision_12: 0.8698 - recall_12: 0.9085 - mean_squared_error: 0.1179
# Epoch 2/3
# 3664/3664 [==============================] - 73s 20ms/step - loss: 0.2857 - accuracy: 0.8814 - precision_12: 0.9081 - recall_12: 0.9310 - mean_squared_error: 0.0870
# Epoch 3/3
# 3664/3664 [==============================] - 75s 20ms/step - loss: 0.2424 - accuracy: 0.8994 - precision_12: 0.9217 - recall_12: 0.9416 - mean_squared_error: 0.0731
# 287/287 [==============================] - 2s 5ms/step - loss: 0.3412 - accuracy: 0.8513 - precision_12: 0.9120 - recall_12: 0.8802 - mean_squared_error: 0.1059
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_13 (Embedding)    (None, None, 16)          1106944
#
#  lstm_4 (LSTM)               (None, 32)                6272
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_22 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 1,113,249
# Trainable params: 1,113,249
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 3664/3664 [==============================] - 76s 20ms/step - loss: 0.3698 - accuracy: 0.8376 - precision_13: 0.8707 - recall_13: 0.9111 - mean_squared_error: 0.1167
# Epoch 2/3
# 3664/3664 [==============================] - 72s 20ms/step - loss: 0.2842 - accuracy: 0.8793 - precision_13: 0.9070 - recall_13: 0.9286 - mean_squared_error: 0.0869
# Epoch 3/3
# 3664/3664 [==============================] - 73s 20ms/step - loss: 0.2380 - accuracy: 0.9030 - precision_13: 0.9247 - recall_13: 0.9429 - mean_squared_error: 0.0712
# 287/287 [==============================] - 2s 5ms/step - loss: 0.3287 - accuracy: 0.8556 - precision_13: 0.8972 - recall_13: 0.9076 - mean_squared_error: 0.1020

# %% [markdown]
# CV Metrics

# %%
for j, name in enumerate(model.metrics_names):
    print(f"{name}:", np.mean([score[model.metrics_names.index(name)] for score in scores]))
# Out:
# loss: 0.3521828711032867
# accuracy: 0.851521098613739
# precision_13: 0.8943051934242249
# recall_13: 0.9028311848640442
# mean_squared_error: 0.10781340450048446

# %% [markdown]
# Test Metrics

# %%
model = LSTM_Model()
model.fit(sequences_train, y_train, epochs=3, batch_size=10, verbose=1)
metrics = model.evaluate(sequences_test, y_test, verbose=1)
# Out:
# Epoch 1/3
# 4580/4580 [==============================] - 91s 19ms/step - loss: 0.3650 - accuracy: 0.8396 - precision_14: 0.8732 - recall_14: 0.9117 - mean_squared_error: 0.1148
# Epoch 2/3
# 4580/4580 [==============================] - 86s 19ms/step - loss: 0.2841 - accuracy: 0.8812 - precision_14: 0.9088 - recall_14: 0.9298 - mean_squared_error: 0.0866
# Epoch 3/3
# 4580/4580 [==============================] - 89s 20ms/step - loss: 0.2431 - accuracy: 0.8983 - precision_14: 0.9210 - recall_14: 0.9407 - mean_squared_error: 0.0737
# 358/358 [==============================] - 3s 5ms/step - loss: 0.3528 - accuracy: 0.8482 - precision_14: 0.9116 - recall_14: 0.8766 - mean_squared_error: 0.1085
